# %%
import pandas as pd

for file in ["accounts_clean.csv", "usage_events_clean.csv", "support_tickets_clean.csv", 
             "invoices_clean.csv", "renewals_clean.csv","nps_clean.csv"]:
    df = pd.read_csv(f"../Data/Cleaned/{file}")
    print(f"--- {file} ---")
    print(df.info())
    print(df.head())
# Out:
# --- accounts_clean.csv ---
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   account_id       500 non-null    int64
#  1   company          500 non-null    str
#  2   tier             500 non-null    str
#  3   region           500 non-null    str
#  4   arr              500 non-null    int64
#  5   contract_start   500 non-null    str
#  6   contract_end     500 non-null    str
#  7   account_manager  500 non-null    str
# dtypes: int64(2), str(6)
# memory usage: 31.4 KB
# None
#    account_id                       company      tier         region    arr  \
# 0           1        Jones, Snyder and Bass  Business           APAC  15860
# 1           2                     Frost Inc  Business         Europe  20191
# 2           3  Herrera, Adkins and Andersen   Starter  North America   3638
# ...

# %%
log = pd.read_csv("../Data/data_lineage_log.csv")
print(log.head(20))
# Out:
#                      timestamp            table                issue  \
# 0   2026-04-05 21:20:13.530364         accounts       duplicate_rows
# 1   2026-04-05 21:20:13.570423     usage_events       duplicate_rows
# 2   2026-04-05 21:20:13.573302  support_tickets       duplicate_rows
# 3   2026-04-05 21:20:13.578733         invoices       duplicate_rows
# 4   2026-04-05 21:20:13.592434         accounts      account_manager
# 5   2026-04-05 21:20:13.626980     usage_events          usage_count
# 6   2026-04-05 21:20:13.638536  support_tickets           account_id
# 7   2026-04-05 21:20:13.654004         invoices        discount_code
# 8   2026-04-05 21:20:13.671710         renewals  orphaned_account_id
# 9   2026-04-05 21:20:13.682004         invoices  paid_before_invoice
# 10  2026-04-05 21:20:13.686176         invoices  currency_conversion
#
#     rows_affected                                 action
# 0               5                     removed duplicates
# ...

# %%
for file in ["accounts_clean.csv", "usage_events_clean.csv", "support_tickets_clean.csv", 
             "invoices_clean.csv", "renewals_clean.csv","nps_clean.csv"]:
    df = pd.read_csv(f"../Data/Cleaned/{file}")
    print(file, "\n", df.isna().sum())
    print("---\n")
    print("Duplicates :=", df.duplicated().sum())
    print("---\n")
# Out:
# accounts_clean.csv
#  account_id         0
# company            0
# tier               0
# region             0
# arr                0
# contract_start     0
# contract_end       0
# account_manager    0
# dtype: int64
# ---
#
# Duplicates := 0
# ---
#
# usage_events_clean.csv
#  event_id       0
# account_id     0
# week_start     0
# tier           0
# feature        0
# usage_count    0
# dtype: int64
# ---
#
# Duplicates := 0
# ---
#
# support_tickets_clean.csv
#  ticket_id           0
# account_id          0
# created_at          0
# category            0
# resolution_hours    0
# sentiment_score     0
# dtype: int64
# ---
#
# Duplicates := 0
# ---
#
# invoices_clean.csv
#  invoice_id       0
# account_id       0
# invoice_date     0
# due_date         0
# paid_date        0
# amount           0
# currency         0
# discount_code    0
# payment_terms    0
# dtype: int64
# ---
#
# Duplicates := 0
# ---
#
# renewals_clean.csv
#  renewal_id      0
# account_id      0
# ...
